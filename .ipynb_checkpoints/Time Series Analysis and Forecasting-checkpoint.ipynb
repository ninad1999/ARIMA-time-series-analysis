# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
# %matplotlib inline

# %%
airline = pd.read_csv('airline_passengers.csv')
airline
# Out:
#                                                  Month  \
# 0                                              1949-01
# 1                                              1949-02
# 2                                              1949-03
# 3                                              1949-04
# 4                                              1949-05
# ..                                                 ...
# 140                                            1960-09
# 141                                            1960-10
# 142                                            1960-11
# 143                                            1960-12
# 144  International airline passengers: monthly tota...
#
#      Thousands of Passengers
# 0                      112.0
# 1                      118.0
# 2                      132.0
# 3                      129.0
# 4                      121.0
# ..                       ...
# 140                    508.0
# 141                    461.0
# 142                    390.0
# ...

# %%
# Dropping the last NaN row
airline.drop(144, axis=0, inplace=True)

# %%
airline
# Out:
#        Month  Thousands of Passengers
# 0    1949-01                    112.0
# 1    1949-02                    118.0
# 2    1949-03                    132.0
# 3    1949-04                    129.0
# 4    1949-05                    121.0
# ..       ...                      ...
# 139  1960-08                    606.0
# 140  1960-09                    508.0
# 141  1960-10                    461.0
# 142  1960-11                    390.0
# 143  1960-12                    432.0
#
# [144 rows x 2 columns]

# %%
# converting Month column from string object to a datetime object
airline['Month'] = pd.to_datetime(airline['Month'])

# %%
# Resetting the Month column as the new index column
airline.set_index('Month', inplace=True)

# %%
airline
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                    112.0
# 1949-02-01                    118.0
# 1949-03-01                    132.0
# 1949-04-01                    129.0
# 1949-05-01                    121.0
# ...                             ...
# 1960-08-01                    606.0
# 1960-09-01                    508.0
# 1960-10-01                    461.0
# 1960-11-01                    390.0
# 1960-12-01                    432.0
#
# [144 rows x 1 columns]

# %% [markdown]
# ### Let's visualize the data

# %%
timeseries = airline['Thousands of Passengers']
timeseries.plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# It can be seen that the data is seasonal with an increasing trend. The number of passengers travelling hike up during the summer months while it drops during the winter months

# %% [markdown]
# The initial increasing trend seems to be slower and more linear while in the later years, it seems to be increasing at an exponential pace.

# %%
timeseries.rolling(12).mean().plot(label='12 Month Rolling Mean')
timeseries.rolling(12).std().plot(label='12 Month Rolling Std Deviation')
timeseries.plot(label='Original Data', figsize=(10,6))
plt.legend();

# %% [markdown]
# We can see that the rolling standard deviation is pretty constant over the years, and is not changing a lot. We can also see the upward trend in the simple moving average.

# %%
timeseries.rolling(12).mean().plot(label='12 Month Rolling Mean')
timeseries.plot(label='Original Data', figsize=(10,6))
plt.legend();

# %%
timeseries.ewm(12).mean().plot(label='12 Month Exponential Weighted Moving Average')
timeseries.plot(figsize=(10,6), label='Original Data')
plt.legend();

# %% [markdown]
# Even through exponential smoothing, we can see similar results, but now more weight has been allocated to the more recent data points rather than all data points being equally weighted like in the Simple Moving Average

# %% [markdown]
# ### ETS Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# ####  Reviewing the line plot, it suggests that there may be a linear trend, but it is hard to be sure from eye-balling. There is also seasonality, but the amplitude (height) of the cycles appears to be increasing, suggesting that it is multiplicative.

# %%
decomposition = seasonal_decompose(airline['Thousands of Passengers'], model='multiplicative')  
fig = plt.figure()  
fig = decomposition.plot()  
fig.set_size_inches(10, 8)

# %% [markdown]
# Now we can clearly see the Error, Trend, and the Seasonality factors of the dataset

# %% [markdown]
# ### Augmented Dickey-Fuller Test for Stationarity

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_check(time_series):
    """
    Pass in a time series, returns ADF report
    """
    result = adfuller(time_series)
    print('Augmented Dickey-Fuller Test:')
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']

    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adf_check(timeseries)
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : 0.8153688792060512
# p-value : 0.991880243437641
# #Lags Used : 13
# Number of Observations Used : 130
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
# Using the adf test, we can see that there is a weak evidence against the null hypothesis and hence our time
# series is non stationary
# This means that the timeseries needs to be differenced and made stationary

# %% [markdown]
# ### Differencing the time series

# %%
airline['First Difference'] = airline['Thousands of Passengers'] - airline['Thousands of Passengers'].shift(1)

# %%
airline['First Difference'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
# Fromt the plot of the first difference, we can see that the First difference might not be stationary
# but lets confirm using the ADF test.

# %%
adf_check(airline['First Difference'].dropna())
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -2.8292668241699976
# p-value : 0.054213290283825745
# #Lags Used : 12
# Number of Observations Used : 130
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
# The timeseries is still not stationary
# We have seen that the data was seasonal, so we can try taking the seasonal difference of the first difference
# and see if that makes the data stationary

# %%
airline['Seasonal First Difference'] = airline['First Difference'] - airline['First Difference'].shift(12)

# %%
airline['Seasonal First Difference'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
adf_check(airline['Seasonal First Difference'].dropna())
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -15.59561808374634
# p-value : 1.856511600123444e-28
# #Lags Used : 0
# Number of Observations Used : 130
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
# Now we can see that the time series is stationary on taking the seasonal first difference.
# The mean and the variance of the dataset are hence relatively constant over time and the covariance is not a 
# function of time

# %% [markdown]
# ### We can decide whether to use an Auto Regressive model or the Moving Average model for performing forecasting using seasonal ARIMA using the Autocorrelation and Partial Autocorrelation plots

# %% [markdown]
# ### Autocorrelation and Partial Autocorrelation plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(airline['Seasonal First Difference'].dropna(), lags=40)
plot_pacf(airline['Seasonal First Difference'].dropna(), lags=40);
